# %%
from .reverse_norm import ReverseNorm

analysis = "Erythroid_ATAC"
input_paths = "/ceph/project/Wellcome_Discovery/datashare/towilson/Trackhubs/Human/Erythroid/50_Donors_Erythroid/hg38/Unpublished/ATAC/Replicates/Raw"
n_cores = 3
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from .reverse_norm import ReverseNorm
#       3 analysis = "Erythroid_ATAC"
#       4 input_paths = "/ceph/project/Wellcome_Discovery/datashare/towilson/Trackhubs/Human/Erythroid/50_Donors_Erythroid/hg38/Unpublished/ATAC/Replicates/Raw"
#
# ImportError: attempted relative import with no known parent package
